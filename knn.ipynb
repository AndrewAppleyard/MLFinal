# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
d2024 = pd.read_csv("pppub24.csv")
d2023 = pd.read_csv("pppub23.csv")
d2022 = pd.read_csv("pppub22.csv")
d2021 = pd.read_csv("pppub21.csv")

data = pd.concat([d2024, d2023, d2022, d2021], ignore_index=True)
data = data.sample(frac=0.2, random_state=42)

rfe_features100 = data[['HHDFMX', 'POTHVAL', 'RESNSS1', 'RESNSS2', 'RESNSSI1', 'RESNSSI2', 'RETCB_VAL', 'RETCB_YN', 'RINT_SC1', 'RINT_SC2', 'RINT_VAL1', 'RINT_VAL2', 'RINT_YN', 'RNT_VAL', 'RNT_YN', 'SRVS_VAL', 'SS_VAL', 'SS_YN', 'SSI_VAL', 'SSI_YN', 'STRKUC', 'SUBUC', 'SUR_SC1', 'SUR_SC2', 'SUR_VAL1', 'SUR_VAL2', 'SUR_YN', 'TRDINT_VAL', 'TSURVAL1', 'TSURVAL2', 'UC_VAL', 'UC_YN', 'VET_QVA', 'VET_TYP1', 'VET_TYP2', 'VET_TYP3', 'VET_TYP4', 'VET_TYP5', 'VET_VAL', 'VET_YN', 'WC_TYPE', 'WC_VAL', 'WC_YN', 'PAW_MON', 'PAW_TYP', 'PAW_VAL', 'PAW_YN', 'PENINCL', 'PENPLAN', 'WICYN', 'CHCARE_YN', 'CHELSEW_YN', 'CHSP_VAL', 'CHSP_YN', 'CSP_VAL', 'CSP_YN', 'ACTC_CRD', 'CTC_CRD', 'DEP_STAT', 'EIT_CRED', 'FEDTAX_AC', 'FEDTAX_BC', 'FICA', 'FILESTAT', 'MARG_TAX', 'PRSWKXPNS', 'STATETAX_A', 'STATETAX_B', 'PERLIS', 'POV_UNIV', 'COV', 'COV_CYR', 'COV_MULT_CYR', 'NOCOV_CYR', 'NOW_COV', 'NOW_PUB', 'PUB', 'PUB_CYR', 'NOW_DEPPRIV', 'NOW_OUTPRIV', 'NOW_OWNPRIV', 'NOW_PRIV', 'OUTPRIV', 'OWNPRIV', 'PRIV', 'PRIV_CYR', 'DEPGRP', 'GRPFTYP', 'GRPFTYP2', 'MRK', 'NOW_CAID', 'NOW_PCHIP', 'NOW_MCARE', 'NOW_IHSFLG', 'NOW_VACARE', 'PECOULD', 'ESIOFFER']]
rfe_features50 = data[['CHCARE_YN', 'CHELSEW_YN', 'CHSP_VAL', 'CHSP_YN', 'CSP_VAL', 'CSP_YN', 'ACTC_CRD', 'CTC_CRD', 'DEP_STAT', 'EIT_CRED', 'FEDTAX_AC', 'FEDTAX_BC', 'FICA', 'FILESTAT', 'MARG_TAX', 'PRSWKXPNS', 'STATETAX_A', 'STATETAX_B', 'PERLIS', 'POV_UNIV', 'COV', 'COV_CYR', 'COV_MULT_CYR', 'NOCOV_CYR', 'NOW_COV', 'NOW_PUB', 'PUB', 'DEPPRIV', 'NOW_DEPPRIV', 'NOW_OUTPRIV', 'NOW_OWNPRIV', 'NOW_PRIV', 'OUTPRIV', 'OWNPRIV', 'PRIV', 'PRIV_CYR', 'GRP', 'GRPFTYP', 'GRPFTYP2', 'NOW_MCAID', 'NOW_CAID', 'NOW_PCHIP', 'NOW_MCARE', 'NOW_IHSFLG', 'ESICOULD']]
rfe_features20 = data[['CSP_VAL', 'CSP_YN', 'FEDTAX_AC', 'FEDTAX_BC', 'FICA', 'FILESTAT', 'PRSWKXPNS', 'STATETAX_A', 'STATETAX_B', 'PERLIS', 'COV_MULT_CYR', 'DEPPRIV', 'NOW_OWNPRIV', 'OWNPRIV', 'GRPFTYP2', 'NOW_MCARE']]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 d2022 = pd.read_csv("pppub22.csv")
#       4 d2021 = pd.read_csv("pppub21.csv")
# ----> 6 data = pd.concat([d2024, d2023, d2022, d2021], ignore_index=True)
#       7 data = data.sample(frac=0.2, random_state=42)
#       9 rfe_features100 = data[['HHDFMX', 'POTHVAL', 'RESNSS1', 'RESNSS2', 'RESNSSI1', 'RESNSSI2', 'RETCB_VAL', 'RETCB_YN', 'RINT_SC1', 'RINT_SC2', 'RINT_VAL1', 'RINT_VAL2', 'RINT_YN', 'RNT_VAL', 'RNT_YN', 'SRVS_VAL', 'SS_VAL', 'SS_YN', 'SSI_VAL', 'SSI_YN', 'STRKUC', 'SUBUC', 'SUR_SC1', 'SUR_SC2', 'SUR_VAL1', 'SUR_VAL2', 'SUR_YN', 'TRDINT_VAL', 'TSURVAL1', 'TSURVAL2', 'UC_VAL', 'UC_YN', 'VET_QVA', 'VET_TYP1', 'VET_TYP2', 'VET_TYP3', 'VET_TYP4', 'VET_TYP5', 'VET_VAL', 'VET_YN', 'WC_TYPE', 'WC_VAL', 'WC_YN', 'PAW_MON', 'PAW_TYP', 'PAW_VAL', 'PAW_YN', 'PENINCL', 'PENPLAN', 'WICYN', 'CHCARE_YN', 'CHELSEW_YN', 'CHSP_VAL', 'CHSP_YN', 'CSP_VAL', 'CSP_YN', 'ACTC_CRD', 'CTC_CRD', 'DEP_STAT', 'EIT_CRED', 'FEDTAX_AC', 'FEDTAX_BC', 'FICA', 'FILESTAT', 'MARG_TAX', 'PRSWKXPNS', 'STATETAX_A', 'STATETAX_B', 'PERLIS', 'POV_UNIV', 'COV', 'COV_CYR', 'COV_MULT_CYR', 'NOCOV_CYR', 'NOW_COV', 'NOW_PUB', 'PUB', 'PUB_CYR', 'NOW_DEPPRIV', 'NOW_OUTPRIV', 'NOW_OWNPRIV', 'NOW_PRIV', 'OUTPRIV', 'OWNPRIV', 'PRIV', 'PRIV_CYR', 'DEPGRP', 'GRPFTYP', 'GRPFTYP2', 'MRK', 'NOW_CAID', 'NOW_PCHIP', 'NOW_MCARE', 'NOW_IHSFLG', 'NOW_VACARE', 'PECOULD', 'ESIOFFER']]
#
# File c:\Users\Andrew\Desktop\ML\venv\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File c:\Users\Andrew\Desktop\ML\venv\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File c:\Users\Andrew\Desktop\ML\venv\Lib\site-packages\pandas\core\internals\concat.py:177, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     167 vals = [ju.block.values for ju in join_units]
#     169 if not blk.is_extension:
#     170     # _is_uniform_join_units ensures a single dtype, so
#     171     #  we can use np.concatenate, which is more performant
#    (...)    175     # expected "Union[_SupportsArray[dtype[Any]],
#     176     # _NestedSequence[_SupportsArray[dtype[Any]]]]"
# --> 177     values = np.concatenate(vals, axis=1)  # type: ignore[arg-type]
#     178 elif is_1d_only_ea_dtype(blk.dtype):
#     179     # TODO(EA2D): special-casing not needed with 2D EAs
#     180     values = concat_compat(vals, axis=0, ea_compat_axis=True)
#
# KeyboardInterrupt:

# %%
X = rfe_features100
y = data['PTOT_R']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

clf = KNeighborsClassifier(n_neighbors=5, metric='manhattan', weights='distance')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print("Training accuracy:", clf.score(X_train, y_train))
print("Test accuracy:", clf.score(X_test, y_test))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

#precision - percent of correct predictions
#recall - percent of samples of class that were correct
#f1 - balance between precision and recall
# Out:
# Training accuracy: 0.8183723449347714
# Test accuracy: 0.7421570243393221
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3682
#            1       0.94      0.99      0.97      2539
#            2       0.70      0.75      0.73       253
#            3       0.74      0.70      0.72       356
#            4       0.74      0.76      0.75       345
#            5       0.74      0.82      0.78       540
#            6       0.74      0.74      0.74       379
#            7       0.74      0.77      0.76       466
#            8       0.70      0.70      0.70       371
#            9       0.66      0.73      0.69       495
#           10       0.62      0.58      0.60       369
#           11       0.63      0.69      0.66       483
#           12       0.56      0.54      0.55       313
#           13       0.59      0.67      0.62       512
#           14       0.51      0.42      0.46       229
#           15       0.56      0.62      0.59       404
#           16       0.43      0.41      0.42       204
#           17       0.55      0.63      0.59       467
#           18       0.35      0.28      0.31       178
#           19       0.50      0.50      0.50       313
#           20       0.35      0.35      0.35       189
#           21       0.53      0.57      0.55       440
#           22       0.33      0.23      0.27       173
#           23       0.41      0.42      0.42       259
#           24       0.33      0.20      0.25       135
#           25       0.45      0.54      0.49       332
#           26       0.25      0.19      0.22       108
#           27       0.38      0.33      0.35       211
#           28       0.23      0.14      0.18        97
#           29       0.43      0.41      0.42       259
#           30       0.27      0.15      0.19       119
#           31       0.33      0.29      0.31       190
#           32       0.09      0.05      0.06        83
#           33       0.41      0.34      0.37       200
#           34       0.19      0.06      0.10        78
#           35       0.40      0.28      0.33       131
#           36       0.40      0.09      0.15        65
#           37       0.40      0.30      0.34       135
#           38       0.12      0.04      0.06        49
#           39       0.41      0.17      0.24        71
#           40       0.20      0.06      0.09        52
#           41       0.86      0.93      0.89      1927
#
#     accuracy                           0.74     18201
#    macro avg       0.49      0.46      0.47     18201
# weighted avg       0.73      0.74      0.73     18201

# %%
X = rfe_features100
y = data['PTOT_R']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

clf = KNeighborsClassifier(n_neighbors=5)

param_grid = {
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid_search = GridSearchCV( estimator=clf, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=1, verbose=2)

grid_search.fit(X_train, y_train)

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ..................metric=euclidean, weights=uniform; total time=   1.3s
# [CV] END ..................metric=euclidean, weights=uniform; total time=   1.3s
# [CV] END ..................metric=euclidean, weights=uniform; total time=   1.2s
# [CV] END ..................metric=euclidean, weights=uniform; total time=   1.2s
# [CV] END ..................metric=euclidean, weights=uniform; total time=   1.2s
# [CV] END .................metric=euclidean, weights=distance; total time=   1.0s
# [CV] END .................metric=euclidean, weights=distance; total time=   1.2s
# [CV] END .................metric=euclidean, weights=distance; total time=   1.0s
# [CV] END .................metric=euclidean, weights=distance; total time=   1.2s
# [CV] END .................metric=euclidean, weights=distance; total time=   1.5s
# [CV] END ..................metric=manhattan, weights=uniform; total time=   8.4s
# [CV] END ..................metric=manhattan, weights=uniform; total time=   8.8s
# [CV] END ..................metric=manhattan, weights=uniform; total time=   8.8s
# [CV] END ..................metric=manhattan, weights=uniform; total time=   9.7s
# [CV] END ..................metric=manhattan, weights=uniform; total time=28.1min
# [CV] END .................metric=manhattan, weights=distance; total time=   7.9s
# [CV] END .................metric=manhattan, weights=distance; total time=   7.3s
# [CV] END .................metric=manhattan, weights=distance; total time=   7.0s
# [CV] END .................metric=manhattan, weights=distance; total time=   6.1s
# [CV] END .................metric=manhattan, weights=distance; total time=   5.9s
# [CV] END ..................metric=minkowski, weights=uniform; total time=   1.1s
# [CV] END ..................metric=minkowski, weights=uniform; total time=   1.1s
# [CV] END ..................metric=minkowski, weights=uniform; total time=   1.1s
# [CV] END ..................metric=minkowski, weights=uniform; total time=   1.1s
# [CV] END ..................metric=minkowski, weights=uniform; total time=   1.0s
# [CV] END .................metric=minkowski, weights=distance; total time=   1.1s
# [CV] END .................metric=minkowski, weights=distance; total time=   1.2s
# [CV] END .................metric=minkowski, weights=distance; total time=   1.1s
# [CV] END .................metric=minkowski, weights=distance; total time=   1.1s
# [CV] END .................metric=minkowski, weights=distance; total time=   0.9s
# {'metric': 'manhattan', 'weights': 'distance'}
# 0.7292422536270373

# %%
X = rfe_features100
y = data['PTOT_R']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

K = []
training = []
test = []
scores = {}

for k in range(2, 15):
    clf = KNeighborsClassifier(n_neighbors = k)
    clf.fit(X_train, y_train)

    training_score = clf.score(X_train, y_train)
    test_score = clf.score(X_test, y_test)
    K.append(k)

    training.append(training_score)
    test.append(test_score)
    scores[k] = [training_score, test_score]

for keys, values in scores.items():
    print(keys, ':', values)

# 20 features - 5 min
#2 : [0.7403098949748034, 0.5978242953683863]
#3 : [0.7080252437243912, 0.608922586671062]
#4 : [0.6908585692083078, 0.6129882973462997]
#5 : [0.6815570103141336, 0.6137574858524257]
#6 : [0.6753402722177743, 0.6135377177078183]
#7 : [0.6708190081476946, 0.6125487610570848]
#8 : [0.6648377525549851, 0.6150211526839184]
#9 : [0.6607403569914755, 0.6154057469369815]
# 100 features - 10 min
#2 : [0.8579098572976028, 0.7014999175869457]
#3 : [0.8240710215231009, 0.709246744684358]
#4 : [0.8095417510478972, 0.7134772814680512]
#5 : [0.8014176046719729, 0.7163892093840998]
#6 : [0.7907737955069938, 0.7151804845887588]
#7 : [0.7850044741675694, 0.7135322235042031]
#8 : [0.7795412800828898, 0.713587165540355]
#9 : [0.7723826119719305, 0.7118290203834954]
#10 : [0.7683323129091508, 0.7116641942750398]
#11 : [0.7644703998492912, 0.7117740783473435]
#12 : [0.7606555832901616, 0.7093566287566617]
#13 : [0.756558187726652, 0.7085324982143838]
#14 : [0.7527904676682522, 0.7074885995274985]
# Out:
# 2 : [0.8579098572976028, 0.7014999175869457]
# 3 : [0.8240710215231009, 0.709246744684358]
# 4 : [0.8095417510478972, 0.7134772814680512]
# 5 : [0.8014176046719729, 0.7163892093840998]
# 6 : [0.7907737955069938, 0.7151804845887588]
# 7 : [0.7850044741675694, 0.7135322235042031]
# 8 : [0.7795412800828898, 0.713587165540355]
# 9 : [0.7723826119719305, 0.7118290203834954]
# 10 : [0.7683323129091508, 0.7116641942750398]
# 11 : [0.7644703998492912, 0.7117740783473435]
# 12 : [0.7606555832901616, 0.7093566287566617]
# 13 : [0.756558187726652, 0.7085324982143838]
# 14 : [0.7527904676682522, 0.7074885995274985]
